# %% [markdown]
# <a href="https://colab.research.google.com/github/darjiavani/college-website/blob/main/object_ditection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install ultralytics
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
result = model("/people.jpeg")
result[0].show()
# Out:
# image 1/1 /people.jpeg: 448x640 15 persons, 168.9ms
# Speed: 5.4ms preprocess, 168.9ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=540x360>

# %%
# !pip -q install ultralytics
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
result = model("/vehicle.jpeg")
result[0].show()
# Out:
# image 1/1 /vehicle.jpeg: 416x640 1 person, 9 cars, 1 motorcycle, 1 bus, 1 truck, 158.9ms
# Speed: 3.2ms preprocess, 158.9ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# <PIL.Image.Image image mode=RGB size=1246x750>

# %%
# !pip -q install ultralytics
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
result = model("/fruits.jpeg")
result[0].show()
# Out:
# image 1/1 /fruits.jpeg: 320x640 3 bananas, 9 apples, 8 oranges, 151.0ms
# Speed: 2.0ms preprocess, 151.0ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=900x450>

# %%
# !pip -q install ultralytics
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
result = model("/vegetable.jpeg")
result[0].show()
# Out:
# image 1/1 /vegetable.jpeg: 480x640 1 fork, 1 bowl, 2 broccolis, 5 carrots, 190.1ms
# Speed: 2.9ms preprocess, 190.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=400x300>

# %%
# !pip -q install ultralytics
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
result = model("/devices.jpeg")
result[0].show()
# Out:
# image 1/1 /devices.jpeg: 448x640 1 microwave, 1 refrigerator, 175.1ms
# Speed: 5.6ms preprocess, 175.1ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=1024x700>
